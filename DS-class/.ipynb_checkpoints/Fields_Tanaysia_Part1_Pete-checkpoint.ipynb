# %% [markdown]
# ### I used Anaconda Navigator to open my notebook

# %%
### project 1 by Tanaysia Fields
# I will be building a system that analyzes student
### Table of contents?

# %%
# Who:
# What:
# When:
# Where:
# Why:

# %%
# a bulleted list with 4 expected outcomes?

# %%
# table

# %%
# horizontal rule

# %%
{ 
    "Student ID" : "12004037",
'Student Name':'Sarah White',
'GPA':4.0,
'Is_the_student_enrolled':'True',
'Students_major':"Psychology",
'Credits_completed':16,
'Tuition_balance':12000.00,
'Is_on_honor_roll': True
}
# Out:
# {'Student ID': '12004037',
#  'Student Name': 'Sarah White',
#  'GPA': 4.0,
#  'Is_the_student_enrolled': 'True',
#  'Students_major': 'Psychology',
#  'Credits_completed': 16,
#  'Tuition_balance': 12000.0,
#  'Is_on_honor_roll': True}

# %% [markdown]
# # Tanaysia

# %% [markdown]
# *hi*

# %% [markdown]
# | A|B|C|
# |-|-|-|
# |1|2|3|
# |-|-|-|
